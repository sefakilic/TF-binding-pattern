# %%
from IPython.display import Image, display
import os
import glob
import motif_profile

motif_files = glob.glob('./data/*.txt')
for motif_file in motif_files:
    sites = motif_profile.load_sites(motif_file)
    seq_logo_file = motif_file.replace('.txt', '.png')
    print motif_file
    display(Image(filename=seq_logo_file))
    motif_profile.find_pattern(sites)
    print '-' * 80
    print ''
# Out:
# ./data/AdpA_S_coelicolor.txt
# single-box (0,)
# --------------------------------------------------------------------------------
#
# ./data/AlgR_P_aeruginosa.txt
# inverted-repeat (1.9733743852353096, (5, 9), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/AmpR_P_aeruginosa.txt
# inverted-repeat (1.0198905332568045, (0, 4), (4, 8))
# --------------------------------------------------------------------------------
#
# ./data/AmrZ_P_aeruginosa.txt
# inverted-repeat (3.19235862689517, (4, 8), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/AraC_E_coli.txt
# direct-repeat (3.7047537833493114, (0, 4), (15, 19))
# --------------------------------------------------------------------------------
#
# ./data/ArcA_E_coli.txt
# direct-repeat (4.50942004206885, (2, 6), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/ArcA_S_oneidensis.txt
# direct-repeat (4.831010130810188, (0, 4), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/ArgR_P_aeruginosa.txt
# direct-repeat (4.12339647205149, (2, 6), (23, 27))
# --------------------------------------------------------------------------------
#
# ./data/BldD_S_coelicolor.txt
# inverted-repeat (4.002952055088101, (1, 5), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/CcpA_B_subtilis.txt
# inverted-repeat (3.0651233370721225, (10, 14), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/CcpA_C_difficile.txt
# inverted-repeat (4.124134676934887, (4, 8), (8, 12))
# --------------------------------------------------------------------------------
#
# ./data/CcpA_L_lactis.txt
# inverted-repeat (2.4729398128119553, (3, 7), (7, 11))
# --------------------------------------------------------------------------------
#
# ./data/CcpA_S_pneumoniae.txt
# inverted-repeat (3.270700470152605, (3, 7), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/CcpA_S_suis.txt
# direct-repeat (2.8552083342607055, (5, 9), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/CodY_B_anthracis.txt
# inverted-repeat (2.4210428424374846, (3, 7), (7, 11))
# --------------------------------------------------------------------------------
#
# ./data/CodY_L_lactis.txt
# inverted-repeat (4.702822566627066, (0, 4), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/CodY_S_pyogenes.txt
# inverted-repeat (6.079200199804038, (3, 7), (8, 12))
# --------------------------------------------------------------------------------
#
# ./data/CRP_E_coli.txt
# inverted-repeat (6.119005331371578, (4, 8), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/CRP_V_vulnificus.txt
# direct-repeat (1.7562123007159864, (10, 14), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/CRP_Y_pestis.txt
# inverted-repeat (5.482691900975903, (5, 9), (15, 19))
# --------------------------------------------------------------------------------
#
# ./data/CsgD_E_coli.txt
# direct-repeat (1.1920746165145857, (0, 4), (9, 13))
# --------------------------------------------------------------------------------
#
# ./data/CtrA_C_crescentus.txt
# inverted-repeat (4.77852641948814, (1, 5), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/DosR_M_tuberculosis.txt
# inverted-repeat (3.82040700436429, (2, 6), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/EspR_M_tuberculosis.txt
# single-box (0,)
# --------------------------------------------------------------------------------
#
# ./data/ExpR_S_meliloti.txt
# inverted-repeat (1.730196060766825, (3, 7), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/Fur_A_ferrooxidans.txt
# inverted-repeat (2.5198454738625222, (7, 11), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/Fur_A_salmonicida.txt
# inverted-repeat (2.665891030016067, (5, 9), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/Fur_B_subtilis.txt
# inverted-repeat (5.41176430250643, (5, 9), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/Fur_C_crescentus.txt
# inverted-repeat (5.118997084942461, (2, 6), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/Fur_E_coli.txt
# inverted-repeat (4.19123340992578, (5, 9), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/Fur_H_pylori.txt
# inverted-repeat (4.427044037887142, (9, 13), (20, 24))
# --------------------------------------------------------------------------------
#
# ./data/Fur_L_monocytogenes.txt
# inverted-repeat (6.083734039133171, (7, 11), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/Fur_N_gonorrhoeae.txt
# direct-repeat (1.7540458300280048, (12, 16), (18, 22))
# --------------------------------------------------------------------------------
#
# ./data/Fur_P_aeruginosa.txt
# inverted-repeat (3.400165092863319, (2, 6), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/Fur_P_syringae.txt
# inverted-repeat (2.277983538859173, (4, 8), (9, 13))
# --------------------------------------------------------------------------------
#
# ./data/Fur_S_enterica.txt
# inverted-repeat (2.9316239611322787, (3, 7), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/Fur_V_cholerae.txt
# inverted-repeat (3.1801773632097063, (1, 5), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/Fur_Y_pestis.txt
# inverted-repeat (3.8872123930478555, (8, 12), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/GlnR_S_erythraea.txt
# direct-repeat (2.799675082837608, (1, 5), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/GlxR_C_glutamicum.txt
# inverted-repeat (3.3311471590094586, (0, 4), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/H-NS_V_cholerae.txt
# inverted-repeat (0.7828753445859787, (0, 4), (4, 8))
# --------------------------------------------------------------------------------
#
# ./data/HapR_V_cholerae.txt
# direct-repeat (2.757248501011206, (2, 6), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/HexR_S_oneidensis.txt
# inverted-repeat (5.383376260324612, (1, 5), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/HgtR_G_sulfurreducens.txt
# direct-repeat (7.132754443707408, (5, 9), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/HrpX_X_oryzae.txt
# direct-repeat (4.964529780138326, (0, 4), (20, 24))
# --------------------------------------------------------------------------------
#
# ./data/IHF_P_putida.txt
# inverted-repeat (2.0326452168809004, (2, 6), (8, 12))
# --------------------------------------------------------------------------------
#
# ./data/IolR_C_crescentus.txt
# inverted-repeat (3.955641316726272, (0, 4), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/LasR_P_aeruginosa.txt
# inverted-repeat (2.061837262632467, (3, 7), (15, 19))
# --------------------------------------------------------------------------------
#
# ./data/LexA_B_subtilis.txt
# inverted-repeat (5.323600123717192, (2, 6), (8, 12))
# --------------------------------------------------------------------------------
#
# ./data/LexA_C_crescentus.txt
# direct-repeat (6.650645139516308, (3, 7), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/LexA_C_glutamicum.txt
# inverted-repeat (3.806821656958127, (3, 7), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/LexA_E_coli.txt
# inverted-repeat (6.19520155535236, (2, 6), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/LexA_L_monocytogenes.txt
# inverted-repeat (6.006148489091031, (5, 9), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/LexA_M_tuberculosis.txt
# inverted-repeat (6.18311784425351, (3, 7), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/LexA_P_aeruginosa.txt
# inverted-repeat (5.7871399938025565, (2, 6), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/LexA_P_difficile.txt
# inverted-repeat (5.303665255962429, (2, 6), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/LexA_P_putida.txt
# inverted-repeat (5.725599608546124, (3, 7), (15, 19))
# --------------------------------------------------------------------------------
#
# ./data/LexA_S_aureus.txt
# inverted-repeat (5.711190262177438, (2, 6), (8, 12))
# --------------------------------------------------------------------------------
#
# ./data/LexA_S_meliloti.txt
# direct-repeat (5.655362489212935, (1, 5), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/LexA_V_parahaemolyticus.txt
# inverted-repeat (6.457317388904512, (3, 7), (15, 19))
# --------------------------------------------------------------------------------
#
# ./data/Lrp_E_coli.txt
# inverted-repeat (2.0510303148633082, (0, 4), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/LuxR_V_campbellii.txt
# inverted-repeat (2.3046971104263396, (6, 10), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/MatP_E_coli.txt
# inverted-repeat (7.045541994156471, (20, 24), (29, 33))
# --------------------------------------------------------------------------------
#
# ./data/MogR_L_monocytogenes.txt
# inverted-repeat (5.653844427369977, (1, 5), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/NikR_H_pylori.txt
# inverted-repeat (3.7625863387758374, (15, 19), (20, 24))
# --------------------------------------------------------------------------------
#
# ./data/NtcA_N_sp_.txt
# inverted-repeat (2.688423459561781, (0, 4), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/OmpR_S_enterica.txt
# single-box (0,)
# --------------------------------------------------------------------------------
#
# ./data/OmpR_Y_pestis.txt
# direct-repeat (2.8576846051045366, (2, 6), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/OxyR_P_aeruginosa.txt
# inverted-repeat (4.060103034318111, (0, 4), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/PerR_B_subtilis.txt
# inverted-repeat (5.339101483923986, (2, 6), (9, 13))
# --------------------------------------------------------------------------------
#
# ./data/PerR_S_aureus.txt
# inverted-repeat (6.006856162809047, (5, 9), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/PhhR_P_putida.txt
# inverted-repeat (1.9984250350858304, (6, 10), (18, 22))
# --------------------------------------------------------------------------------
#
# ./data/PhoP_E_coli.txt
# direct-repeat (3.7434150101478645, (3, 7), (14, 18))
# --------------------------------------------------------------------------------
#
# ./data/PhoP_S_enterica.txt
# direct-repeat (5.522879622613815, (5, 9), (16, 20))
# --------------------------------------------------------------------------------
#
# ./data/PhoP_Y_pestis.txt
# direct-repeat (3.597216118303427, (1, 5), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/PsrA_P_aeruginosa.txt
# inverted-repeat (6.450860622288278, (1, 5), (9, 13))
# --------------------------------------------------------------------------------
#
# ./data/PvdS_P_aeruginosa.txt
# inverted-repeat (1.1939973490161455, (15, 19), (20, 24))
# --------------------------------------------------------------------------------
#
# ./data/PvdS_P_syringae.txt
# direct-repeat (2.979657073674635, (5, 9), (24, 28))
# --------------------------------------------------------------------------------
#
# ./data/RpoN_S_enterica.txt
# inverted-repeat (2.1845867055631425, (2, 6), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/RpoN_V_cholerae.txt
# inverted-repeat (2.9055541677546843, (2, 6), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/RutR_E_coli.txt
# inverted-repeat (4.180526343622272, (2, 6), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/ToxR_V_cholerae.txt
# direct-repeat (4.627083139049599, (3, 7), (12, 16))
# --------------------------------------------------------------------------------
#
# ./data/ToxT_V_cholerae.txt
# inverted-repeat (1.5370359953896087, (1, 5), (9, 13))
# --------------------------------------------------------------------------------
#
# ./data/Vfr_P_aeruginosa.txt
# inverted-repeat (0.7515023252119895, (1, 5), (11, 15))
# --------------------------------------------------------------------------------
#
# ./data/VqsM_P_aeruginosa.txt
# direct-repeat (0.9632977617819556, (4, 8), (13, 17))
# --------------------------------------------------------------------------------
#
# ./data/Zur_N_meningitidis.txt
# inverted-repeat (3.0457787641699, (1, 5), (10, 14))
# --------------------------------------------------------------------------------
#
# ./data/Zur_P_protegens.txt
# inverted-repeat (5.729955985183197, (2, 6), (11, 15))
# --------------------------------------------------------------------------------
